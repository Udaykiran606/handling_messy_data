# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'customer_id': [1, 2, 3, 4, 2, 5],
    'age':         [25, np.nan, 35, np.nan, np.nan, 40],
    'city':        ['Mumbai', 'Delhi', np.nan, 'Mumbai', 'Delhi', np.nan],
    'gender':      ['Male', 'Female', 'Female', 'Male', 'Female', 'Male'],
    'annual_income': [40000, 80000, 60000, 120000, 80000, 95000]
})

#Impute missing values in age with the median and in city with the mode Remove any duplicate rows
df["age"]= df["age"].fillna(df["age"].median())
df["city"] = df["city"].fillna(df["city"].mode()[0])
df

#Remove any duplicate rows
removing_duplicates = df.drop_duplicates( ['city' , 'age'])
print(removing_duplicates)


from sklearn.preprocessing import LabelEncoder
# Step 2: One-Hot Encoding for 'city'
df = pd.get_dummies(df, columns=['city'])

# Step 3: Label Encoding for 'gender'
le = LabelEncoder()
df['gender'] = le.fit_transform(df['gender'])

# Step 4: Print the resulting dataframe
print(df)


from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Columns to scale
cols = ['age', 'annual_income']

# -------- Min-Max Scaling --------
minmax_scaler = MinMaxScaler()
df_minmax = df.copy()
df_minmax[cols] = minmax_scaler.fit_transform(df_minmax[cols])

print("Min-Max Scaled DataFrame:")
print(df_minmax)


# -------- Standardisation --------
std_scaler = StandardScaler()
df_standard = df.copy()
df_standard[cols] = std_scaler.fit_transform(df_standard[cols])

print("\nStandardized DataFrame:")a
print(df_standard)

# In 2–3 sentences, explain when you would prefer one over the other.
# Use Min-Max Scaling when you need features in a fixed range (0–1), especially for algorithms like neural networks or KNN that rely on distance and are sensitive to scale. Use Standardisation when your data may contain outliers or follows a normal distribution, as it centers the data and is preferred for models like linear regression or SVM.
